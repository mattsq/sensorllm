# %% [markdown]
# # 04 - Results Analysis
#
# Aggregate results across all experiments, generate tables and figures for paper/report.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Summary Table

# %%
# TODO: Build summary table from experiment metrics.jsonl files
