# %% [markdown]
# # 02 - Sensor Transform Comparison
#
# Visually compare spectrogram, CWT scalogram, recurrence plot, and raw image transforms on the same signal.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sensorllm.data.transforms import TRANSFORM_REGISTRY
from sensorllm.data.transforms.raw_image import RawImageTransform

# %% [markdown]
# ## Synthetic Signal

# %%
t = np.linspace(0, 1.0, 4096, dtype=np.float32)
signal = np.sin(2*np.pi*50*t) + 0.5*np.sin(2*np.pi*120*t) + 0.05*np.random.randn(4096)
plt.plot(t[:200], signal[:200])
plt.title("Synthetic vibration signal (first 200 samples)")
plt.show()

# %% [markdown]
# ## Transform Outputs

# %%
# TODO: Apply each registered transform and visualize side by side
