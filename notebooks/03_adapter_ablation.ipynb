# %% [markdown]
# # 03 - Adapter Architecture Ablation
#
# Compare evaluation metrics across adapter types from experiment runs.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Experiment Results

# %%
# TODO: Load metrics.jsonl from each experiment run directory and compare
