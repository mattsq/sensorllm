# %% [markdown]
# # 01 - Aircraft Sensor Data Exploration
#
# EDA: raw sensor signals, statistics, and flight log inspection.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
# Load your sensor data here

# %% [markdown]
# ## Raw Signal Inspection

# %%
# TODO: Load a sample flight file and plot raw channels
# from sensorllm.data.sensors import SENSOR_REGISTRY
